# %%
print("Hello")
# Out:
# Hello

# %%
for i in range(6):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for x in range (0,20,3):
    print(x)
# Out:
# 0
# 3
# 6
# 9
# 12
# 15
# 18

# %%
for x in "Taller de phyton":
    print(x)
# Out:
# T
# a
# l
# l
# e
# r
#
# d
# e
#
# p
# h
# y
# t
# o
# n

# %%
for x in "Taller Phyton":
    if x == "T":
        print(x)
# Out:
# T

# %%
for y in range(10,0,-2):
    print(y)
# Out:
# 10
# 8
# 6
# 4
# 2
